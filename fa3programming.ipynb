# %% [markdown]
# <a href="https://colab.research.google.com/github/jollyjunojuunoh-crypto/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1

name = input("What is your name?:    ")
print(f"Hello, {name} !")

age = int(input("What is your age?:    "))
print(f"You are {age} years old.")

course = input("What is your course?:    ")
print(f"You are studying {course}.")

print(f"{name} is {age} years old, and is studying {course}.")
# Out:
# What is your name?:    z
# Hello, z !
# What is your age?:    1
# You are 1 years old.
# What is your course?:    z
# You are studying z.
# z is 1 years old, and is studying z.

# %%
#fa3prog2

score = int(input("What is your grade on this exam:    "))
if score >= 75:
    print("You passed!")
elif score <=75:
  print("You failed :(")
# Out:
# What is your grade on this exam:    77
# You passed!

# %%
#fa3prog3

name = input("What is your name?:    ")

score = int(input("What is your grade on this exam:    "))
if score >= 90:
    print("A")
elif score >= 80 and 89:
    print("B")
elif score >= 70 and 79:
    print("C")
elif score <=70:
    print("F")
# Out:
# What is your name?:    z
# What is your grade on this exam:    72
# C
